# %% [markdown]
# # Импорт библиотек.

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

from pymorphy2 import MorphAnalyzer
from sklearn import metrics #метрики
from sklearn.metrics import accuracy_score

from gensim.models import Word2Vec

import annoy

# %% [markdown]
# # Просмотр краткого содержания по данным.

# %%
df1 = pd.read_csv('data/ProductsDataset.csv')
df1=df1.loc[:, ['title', 'product_id']]
df1["label"] = np.ones(len(df1), dtype=int)
df1.head()
# Out:
#                   title                product_id  label
# 0     Юбка детская ORBY  58e3cfe6132ca50e053f5f82      1
# 1             Ботильоны  5667531b2b7f8d127d838c34      1
# 2                 Брюки  59534826aaab284cba337e06      1
# 3  Продам детские шапки  57de544096ad842e26de8027      1
# 4                Блузка  5ad4d2626c86cb168d212022      1

# %% [markdown]
# Проверим наличие дубликатов

# %%
df1_dupl=df1[df1.duplicated(['product_id'])]

# %%
df1_dupl
# Out:
#                                                    title product_id  label
# 4650                                        размер 52-54        NaN      1
# 4651                                         взади сетка        NaN      1
# 4652                                          ----------        NaN      1
# 4653                     Могу выслать в любой город Р.Ф.        NaN      1
# 26827     Лампа галогенная GU5.3,GU10 MR16 20,35,50,75Вт        NaN      1
# 26828                                          117шт*15р        NaN      1
# 27016  Кепка Minnie Mouse C прямым козырьком размер 5...        NaN      1
# 27017                                 C прямым козырьком        NaN      1
# 27018                                       Размер 50-54        NaN      1
# 27019                                         ----------        NaN      1
# 27020                    Могу выслать в любой город Р.Ф.        NaN      1
# 27021                                         ----------         22      1

# %%
df1.shape
# Out:
# (35536, 3)

# %% [markdown]
# Возьму ровно столько же строк )

# %%
df2 = pd.read_csv('data/prepared_answers.txt', usecols=[0],sep="\t",nrows=35536).rename(columns={"Unnamed: 0":"title"})
df2["label"] = np.zeros(len(df2), dtype=int)
df2.sample(4)
# Out:
#                                                    title  label
# 19929                                 Ты хитренький?)) .      0
# 11271                                фильмы типа братз .      0
# 12798  посоветуйте клевый триллер:))) мне кажется, чт...      0
# 24243  Когда короли завидуют своим шутам(ну кроме жен...      0

# %%
data = pd.concat([df1, df2])

# %%
data.sample(5)
# Out:
#                                                    title  \
# 700    А вот У МЕНЯ ТАКОЙ ВОТ ВОПРОС ЕСТЬ!! ! АВТОМОБ...
# 34425                                      Норковая шуба
# 17979                                              Туфли
# 469    Написать маленькое сочинение на тему отдых дет...
# 25388                                         Спецодежда
#
#                      product_id  label
# 700                         NaN      0
# 34425  5943bb679380007d657c43e2      1
# 17979  599e779bf20263cb594cce5c      1
# 469                         NaN      0
# 25388  5aeac56d22a44938b31d9c72      1

# %% [markdown]
# ## Осуществлён препроцессинг текста (как минимум удаление знаков препинания, приведение к нижнему регистру, стемминг/лемматизация).

# %%
import string
def clean_text(text):
    # пунктуацию будем удалять в цикле
    for p in string.punctuation:
        if p in text:
            text = text.replace(p, ' ')
    text = text.lower()  # приведение к нижнему регистру
    text = text.strip()  # удаление лишних пробелов с обеих сторон
    words = text.split()  # разбиение текста на слова
    return words

# %%
data['title']
# Out:
# 0                                        Юбка детская ORBY
# 1                                                Ботильоны
# 2                                                    Брюки
# 3                                     Продам детские шапки
# 4                                                   Блузка
#                                ...
# 35531    как мужик двух генералов накормил Как описывае...
# 35532    Как можно заработать БОЛЬШЕ денег - за МЕНЬШЕЕ...
# 35533    выключается видеокарта во время игр. выключает...
# 35534    Ребят!! Нашёл удочку дома))) подскажите сайт, ...
# 35535       зачем нужны виртуальные части тела?))))))))) .
# Name: title, Length: 71072, dtype: object

# %%
data['title'] = data['title'].astype(str)
data['title'] = data['title'].apply(clean_text)

# %%
data['title']
# Out:
# 0                                    [юбка, детская, orby]
# 1                                              [ботильоны]
# 2                                                  [брюки]
# 3                                 [продам, детские, шапки]
# 4                                                 [блузка]
#                                ...
# 35531    [как, мужик, двух, генералов, накормил, как, о...
# 35532    [как, можно, заработать, больше, денег, за, ме...
# 35533    [выключается, видеокарта, во, время, игр, выкл...
# 35534    [ребят, нашёл, удочку, дома, подскажите, сайт,...
# 35535             [зачем, нужны, виртуальные, части, тела]
# Name: title, Length: 71072, dtype: object

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/SEV/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords = nltk.corpus.stopwords.words('russian')

# %%
def remowe_stopwords(tokenised_list):
    text = [word for word in tokenised_list if word not in stopwords]
    return text

data['title'] = data['title'].apply(lambda x: remowe_stopwords(x))

# %%
data
# Out:
#                                                    title  \
# 0                                  [юбка, детская, orby]
# 1                                            [ботильоны]
# 2                                                [брюки]
# 3                               [продам, детские, шапки]
# 4                                               [блузка]
# ...                                                  ...
# 35531  [мужик, двух, генералов, накормил, описывается...
# 35532                [заработать, денег, меньшее, время]
# 35533  [выключается, видеокарта, время, игр, выключае...
# 35534  [ребят, нашёл, удочку, дома, подскажите, сайт,...
# 35535                  [нужны, виртуальные, части, тела]
#
#                      product_id  label
# 0      58e3cfe6132ca50e053f5f82      1
# 1      5667531b2b7f8d127d838c34      1
# 2      59534826aaab284cba337e06      1
# 3      57de544096ad842e26de8027      1
# 4      5ad4d2626c86cb168d212022      1
# ...                         ...    ...
# 35531                       NaN      0
# 35532                       NaN      0
# 35533                       NaN      0
# 35534                       NaN      0
# 35535                       NaN      0
#
# [71072 rows x 3 columns]

# %%
#лемматизация
morpher = MorphAnalyzer()
def lem_words(text):
    text_morph = [morpher.parse(i)[0].normal_form for i in text]
    return text_morph

# %%
data['title']= data['title'].apply(lambda x: lem_words(x))

# %%
data.sample(10)
# Out:
#                                                    title  \
# 9882                       [ползунок, детский, пакет, 0]
# 17005        [отличие, dvd, r, dvd, r, dvd, rw, dvd, rw]
# 9101   [помочь, пожалуйста, котёнок, трое, месячный, ...
# 1972   [какой, учереждение, лпу, государственный, ком...
# 13272                                   [джинсы, турция]
# 15256                                            [кофта]
# 2577                             [фирменный, топ, fendi]
# 22233               [отличаться, диск, dvd, rw, dvd, rw]
# 480                                   [четыре, сословие]
# 7124              [штаны, утеплить, 110р, цена, 2, пара]
#
#                      product_id  label
# 9882   5b1127b1cf689a356b549d42      1
# 17005                       NaN      0
# 9101                        NaN      0
# 1972                        NaN      0
# 13272  5ae048f7bd36c0125a619ab5      1
# 15256  5aeac8b82138bbbc23492ea2      1
# 2577   588773069a64a299b242016c      1
# 22233                       NaN      0
# 480                         NaN      0
# 7124   591ae42b2756ba58431fe233      1

# %%
print('{} - количество пропусков в text'.format(data['label'].isnull().sum()))
print('{} - количество пропусков в label'.format(data['label'].isnull().sum()))
# Out:
# 0 - количество пропусков в text
# 0 - количество пропусков в label

# %% [markdown]
# ## Текст векторизирован любым из изученных способов (CountVectorizer, TfidfVectorizer, HashingVectorizer, Word2Vec).

# %%
X = data['title']
Y = data['label']
X_train, X_test, y_train, y_test = train_test_split(X,Y, train_size=0.7,random_state=42, shuffle=True)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (49750,)
# (21322,)

# %%
# Join the words in each list into a single string
X_train_processed = [' '.join(doc) for doc in X_train]
X_test_processed = [' '.join(doc) for doc in X_test]

# Initialize the TfidfVectorizer
vectorizer = TfidfVectorizer(max_features= 30000)

# %%
X_train_v = vectorizer.fit_transform(X_train_processed)

X_test_v = vectorizer.transform(X_test_processed)

# %%
print(X_train_v.shape)
print(X_test_v.shape)
# Out:
# (49750, 30000)
# (21322, 30000)

# %%
model = LogisticRegression()
model.fit(X_train_v, y_train)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(X_test_v)
accuracy = (predictions == y_test).mean()
accuracy
# Out:
# 0.9748147453334584

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.9748147453334584

# %%
# Обучим модель word2vec на продуктах
mask = (data['label'] == 1)
sentences = data[mask]['title']
model_w2v_prod = Word2Vec(sentences=sentences, vector_size=100, min_count=1, window=10)
model_w2v_prod.save("w2v_model")

# %%
index = annoy.AnnoyIndex(100 ,'angular')

index_map = {}

for row in data.itertuples():
    n_w2v = 0
    index_map[row[0]] = row[0]
    question = row[1]
    vector = np.zeros(100)
    for word in question:
        if word in model_w2v_prod.wv:
            vector += model_w2v_prod.wv[word]
            n_w2v += 1
    if n_w2v > 0:
        vector = vector / n_w2v
    index.add_item(row[0], vector)
        

index.build(10)
index.save('product_ann.ann')
# Out:
# True

# %%
# Assuming model_w2v_prod is your Word2Vec model
#model_w2v_prod = Word2Vec.load("w2v_model")

# Specify the dimension of the vectors in the Word2Vec model
vector_dim = model_w2v_prod.vector_size

# Build the Annoy index
indexer = annoy.AnnoyIndex(vector_dim, 'angular')
for i, word in enumerate(model_w2v_prod.wv.index_to_key):
    indexer.add_item(i, model_w2v_prod.wv[word])
indexer.build(50)  # Build the index with 50 trees for better accuracy

def find_similar_products(query, index, model_w2v_prod):
    query_vector = np.zeros(100)
    n_w2v=0
    for word in query:
        if word in model_w2v_prod.wv:
            query_vector += model_w2v_prod.wv[word]
            n_w2v += 1
    if n_w2v > 0:
        query_vector = query_vector / n_w2v
        
    similar_docs = indexer.get_nns_by_vector(query_vector, n=5)  # Find 5 most similar products
    return similar_docs

# Example usage
query = ['юбка','красная','короткая']
similar_products = find_similar_products(query, indexer, model_w2v_prod)
print(similar_products)
# Out:
# [513, 300, 991, 778, 505]

# %% [markdown]
# Загрузим индекс,словарь и модель  из прошлого юниту ChatBotPractic.

# %%
# Создание нового объекта AnnoyIndex
index = annoy.AnnoyIndex(100, 'angular')

# Загрузка сохраненного индекса из файла 'speaker.ann'
index.load('speaker.ann')

# Теперь индекс готов к использованию в  программе
# Out:
# True

# %%
model_w2v_sp= Word2Vec.load("w2v_model_sp")

# %%
import pickle
 
with open('my_dict.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)

# %%
loaded_dict
# Out:
# {0: 'вопрос о ТДВ)) давно и хорошо отдыхаем)) ЛИЧНО ВАМ здесь кого советовали завести?)) . \n',
#  1: 'меня вобще прикалывает эта тема :). \n',
#  2: 'Если это "счастье " действительно на вас свалилось, лучше пойти в милицию и заявить о находке. Такие деньги просто так не терют, а что самое интересное их неприменно будут искать и поверьте мне найдут, видел подобное в жизни. Можно нарваться на бабушку конечно, которая хотела помоч внуку с покупкой квартиры, а можно на бандитов, которые будут с вами разговаривать иначе чем бабушка с милицией. Выбор за вами, есть еще конечно шанс, что это подарок с выше за котрый с вас никто не спросит, тогда лучше отдать хотябы 500 на благотворительность. дабы не спугнуть удачу!. \n',
#  3: 'ЭБУ — электронный блок управления двигателем автомобиля, его другое название — контроллер. Он принимает информацию от многочисленных датчиков, обрабатывает ее по особым алгоритмам и, отталкиваясь от полученных данных, отдает команды исполнительным устройствам системы.. \n',
#  4: '4. Охотники и Жертвы, Ледяной укус, Поцелуй тьмы, Кровная клятва. \n',
#  5: 'Защита мыслью. <br>Каждый человек должен в отношении вампиров взять для себя за правило: "Нам не страшен серый волк", то есть знать, что конкретный "серый волк" - вампир существует, но воспринимать его следует не как хищника, а как добрую домашнюю собачку. Такая "собачка" быстро почувствует, что вы не "того поля ягода" и быстро отстанет сама. <br>"Витание в облаках". <br>Тоже хороший способ. Мысленно представить себя находящимся в окружении приятных нашим ощущениям белых облаков или сине-голубого неба. Это просто и эффективно. <br>"Подкормка негативом". <br>Вампир хочет кушать? Так дайте ему. Соберите в себе все плохие мысли, эмоции, все то отрицательное, что каким-то образом закралось в организм. И всю эту "тяжесть" отдайте вампиру - пусть подавится. <br>Зеркало <br>При встрече или при общении с неприятным человеком мысленно представить, что между вами зеркальная стена, обращенная отражающей поверхностью к этому человеку. <br>"Дикобраз" <br>Этот способ выглядит следующим образом: человек, который почувствовал опасность, мысленно покрывает свое биополе иглами и шипами. Энергетический вампир, который попробует высосать вашу биоэнергию, будет ощущать боль при прикосновении биополей. <br>Замыкание контура биополя. <br> <br>Существует два способа. Каждый человек выбирает наиболее удобный ему. Первый способ заключается в скрещивании ног и рук при общении с человеком, от которого можно ждать неприятностей. Второй способ заключается в следующем: большой и указательный пальцы одной руки соединить с большим и указательным пальцами другой руки, образуя кольцо, а остальные пальцы каждой руки наложить друг на друга. Оба эти способа очень эффективны, так как благодаря ним замыкается контур биополя, не оставляя пробоин, и энергетический вампир просто не может пробиться через эту защиту и вытянуть нашу биоэнергию. <br> <br>Все приемы нужно делать незаметно, не демонстрируя своих действий и не привлекая внимания окружающих.. \n',
#  28: 'у меня закончилась тупо надо дубликат делать. \n',
#  29: 'Если опять какой-то дурью не закинется, то проиграет, Денис Лебедев бил его много , сильно и практически всегда попадал, Джонс выстоял только благодаря наркоте которой себя накачал. Денис Лебедев ещё и мотивирован на бой запредельно.. \n',
#  30: 'Это укусы клопов<br>Некоторые дауны не знают что капс можно отключить.. \n',
#  31: 'просыпать сахар - к деньгам)). \n',
#  32: 'покрывать позолотой не поможет... воняет.... мыть и дезодорировать, мыть и одеколонить.... \n',
#  33: 'морда станет еще краснее... \n',
#  34: '<p>2NH3+H2SO4 = (NH4)2SO4</p> <p>v(NH3) = 134,4/22,4 = 6 моль</p> <p>по уравнению реакции v(H2SO4) = 1/2 от v(NH3) = 3 моль</p> <p>m(H2SO4) (в-ва) = 3*98 = 294 гр</p> <p>m(H2SO4) (р-ра) = 294/0,78 = 377 гр = 0,377 кг</p> <p>ответ: 0,377 кг</p>. \n',
#  35: '[ссылка заблокирована по решению администрации проекта] <br>пропал он куда-то, Михаил Микеска, может лигу сменил после Сибири и Уфы. \n',
#  36: 'сходи на рынок, тебе там все объяснят и даже попробовать дадут. \n',
#  37: 'А кому ты пишешь? Определись с аудиторией, и тебе все станет ясно.<br>А лучше пиши как пишешь - обо всем и по-разному.<br>Тебе нравятся какие-нить исполнители.. . грамотные? о чем они пишут?<br>Не парься! Будь оригинальным и все. Точка.<br>Я сам пишу.. \n',
#  38: 'в сентябре не даст о себе знать. А на остальной срок нужен расклад карт.. \n',
#  39: 'Ты прелесть моя дорогая. Кофе, да сколько угодно. Сам пью ежедневно не менее 10-чашек.. \n',
#  40: 'лажа! мне вообще этот бред не понравился! фильм для 16-ти летних!. \n',
#  41: 'Ромашка, не болей! Позитивчика тебе!. \n',
#  42: 'И каждый, кто призывает имя Иеговы, спасётся“.Но как призывать того, в кого не поверили? И как поверить в того, о ком не слышали? И как услышать без проповедующего?. \n',
#  43: 'Рассказ «Крыжовник» , входящий в «маленькую трилогию» , написан в июле 1898 г. , сразу после «Человека в футляре» . Есть несколько записей к этому рассказу в дневнике писателя. Вот одна из них: «Заглавие: Крыжовник. X. служит в департаменте, страшно скуп, копит деньги. Мечта: женится, купит имение, будет спать на солнышке, пить на зеленой травке, есть свои щи. Прошло 25, 40, 45 лет. Уж он отказался от женитьбы, мечтает об имении. Наконец 60. Читает многообещающие соблазнительные объявления о сотнях, десятинах, рощах, реках, прудах, мельницах. Отставка. Покупает через комиссионера именьишко на пруде.. . Обходит свой сад и чувствует, что чего-то недостает. Останавливается на мысли, что недостает крыжовника, посылает в питомник. Через 2—3 года, когда у него рак желудка и подходит смерть, ему подают на тарелке его крыжовник. Он поглядел равнодушно» . И другая: «Крыжовник был кисел: „Как глупо”, — сказал чиновник и умер» . К этому же рассказу имеет отношение и следующая запись, в которой видят одну из главных мыслей произведения: «За дверью счастливого человека должен стоять кто-нибудь с молоточком, постоянно стучать и напоминать, что есть несчастные и что после непродолжительного счастья непременно наступит несчастье».. \n',
#  44: 'скорость катера + ск. теч=21 <br>скорость катера - ск. теч=60/4=15 <br>Вычитаем 2 из первого - получаем 2*ск. теч=6, ск. теч. = 3 (км/час) . <br>Как-то так.. \n',
#  45: 'Я то нашёл а ты. \n',
#  46: 'Я вас любил: любовь еще, быть может, <br>В душе моей угасла не совсем; <br>Но пусть она вас больше не тревожит; <br>Я не хочу печалить вас ничем. <br>Я вас любил безмолвно, безнадежно, <br>То робостью, то ревностью томим; <br>Я вас любил так искренно, так нежно, <br>Как дай вам бог любимой быть другим. <br> <br>*** <br> <br>Я помню чудное мгновенье: <br>Передо мной явилась ты, <br>Как мимолетное виденье, <br>Как гений чистой красоты. <br> <br>В томленьях грусти безнадежной <br>В тревогах шумной суеты, <br>Звучал мне долго голос нежный <br>И снились милые черты. <br> <br>Шли годы. Бурь порыв мятежный <br>Рассеял прежние мечты, <br>И я забыл твой голос нежный, <br>Твои небесные черты. <br> <br>В глуши, во мраке заточенья <br>Тянулись тихо дни мои <br>Без божества, без вдохновенья, <br>Без слез, без жизни, без любви. <br> <br>Душе настало пробужденье: <br>И вот опять явилась ты, <br>Как мимолетное виденье, <br>Как гений чистой красоты. <br> <br>И сердце бьется в упоенье, <br>И для него воскресли вновь <br>И божество, и вдохновенье, <br>И жизнь, и слезы, и любовь.<br>. \n',
#  47: 'Елка с гирляндой))) Было. Где-то мкнет, надо к автоэлектрику сам фиг найдешь. \n',
#  48: 'Нет, нет, Варвара, подожди, куда ты, к Птибурдюкову что ли?...<br>Смотри, какие слова я принес тебе....<br>Астра и любовь, любимая, ненаглядная кисочка моя (моя?), хризантема, тюльпан черноглазая, олень темноволосая, чернобровая, персик армянский, роза из Эдема, ласточка чернокрылая, цветок весенняя, королева недостигаемая, солнышка утренняя, лань гордостанная, мечта поэта и муза, песня сереброзвонная, мечта, далекая, осина , фиалка, ручейка горноводная, звезда яркая...,<br><br>. \n',
#  49: 'Есть такое лекарство, оно продаётся без рецепта в любой аптеке или других местах - новое увлечение!!. \n',
#  50: 'Откуда такая роскошь?. \n',
#  51: 'Это двигатель последовательного возбуждения, ещё их называют универсальными, поскольку могут работать как на постоянном, так и на переменном токе. <br> Если менять полярность на половине обмотки возбуждения, то это приводит к обнулению магнитного потока от обмотки возбуждения и двигатель практически превращается в обычный резистор. Вот его и коротит. <br> Для смены направления вращения надо поменять местами контакты на щётках, это внизу рисунка нарисован якорь и у него две щетки. Только там надо быть аккуратным, сами графитовые щетки идут с разъемами, но с оголёнными проводами, и их длины не хватит.. \n',
#  52: 'http://golovolomka.hobby.ru/logic/easy.s...<br>посмотри.. .<br>там головоломки всякие.. .<br>надеюсь, понравятся.. .<br>. \n',
#  53: 'Я этот движок никогда не видел, потому без развернутой системы сложно сказать что-либо конкретное. Но версия у меня есть: по умолчанию, функция mysql_fetch_array() возвращает данные в ассоциативном и числовом представлении, то есть, каждая строка будет продублирована с разными индексами. Если полученный массив неправильно обработать, получится задвоение.<br><br>Если я угадал причину, тогда это вина разработчиков, потому задача выходит за рамки компетенции администратора.. \n',
#  70: 'Это к удачи! пёс верный был! ! прибейте у входа. стеречь будет как пёс и удача. Только прибить надо в верх дугой а не в низ. мнение такое. с уважением Андрей. \n',
#  71: '<p> 1 мировая война началась в 1914 году </p>. \n',
#  72: 'Карп может побеги покусать, если будет голодный. Остальные есть не будут, в том числе и толстолобик. <br>Вот здесь про это много написано www.forumhouse.ru/threads/143310/. \n',
#  73: 'Да мелкая потому что. Изначально рисуй мелкую, тогда и будет нормально. \n',
#  74: '<p> 72-18=54<br>72-100%<br>54*100/72=75%</p>. \n',
#  75: '<p> 3\xa0или\xa04\xa0а\xa0можно\xa0несколько\xa0вриантов\xa0? </p>. \n',
#  76: '<p>Матушка, знавшая наизусть все его свычаи и обычаи, всегда\xa0стараласьзасунуть\xa0несчастную книгу как можно подалее, и таким образом Придворный Календарь не попадался ему на глаза иногда по целым месяцам.Батюшка не\xa0любил\xa0ни\xa0переменять\xa0 свои намерения, ни откладывать их исполнение.Ты\xa0едешь\xa0в Оренбург\xa0служить\xa0под его начальством.В ту же ночь приехал я в Симбирск, где\xa0должен был пробыть\xa0сутки для закупки нужных вещей, что и было поручено Савельичу.Я\xa0стал смотреть\xa0на их игру.Я\xa0стал извиняться.Я\xa0могу\xa0и\xa0подождать, а покаместь поедем к Аринушке.Мне было жаль бедного старика; но я\xa0хотел вырваться\xa0на волю и доказать, что уж я не ребенок.Савельич\xa0поспешил вывезти\xa0меня из проклятого трактира.Я непременно\xa0хотел\xa0с ним\xa0помириться, и не знал с чего начать.</p>. \n',
#  77: 'Пошел дождь и грянул гром.. . <br>Но это было уже потом.. . <br>Потоком мыслей смыло преграды.. . <br>Оригинально... чему все и рады...). \n',
#  78: 'ну давай скинемся на дорогую шлю) (у... и втроем. \n',
#  79: 'учетки с EA перекочевали в оригин, теперь регаться надо там. Origin.com, по идее все должно работать как и раньше.. \n',
#  80: 'Если принтер струйный, то засорилось одно или несколько сопел в печатающей головке.. \n',
#  81: '3) Na2O+2HCl=2NaCl+H2O <br>4P+5O2=2P2O5 <br>Al+3HCl=AlCl3 <br>3Mg+WO3=3MgO+W. \n',
#  82: 'и наказывать тех, кто пользуется этими услугами--не будет спроса и предложение исчезнет.... \n',
#  83: 'Или девушка "шалавой" становится, потому что мужо не знает, что с женой делать.. \n',
#  84: 'Футбол, теннис, шашки, домино. \n',
#  85: 'Тайны политики не всегда лежат на поверхности . Да . и малая доза яда для организма чаще является лекарством - будем считать . что, именно так и расценили творчество этого писателя, которого, надо признать, читают в России - единицы.... \n',
#  86: 'выклочи и включи из розетки, без батарейки. \n',
#  87: 'Прошивка - это замена программного обеспечения телефона... .<br>Нужна она для того, чтобы устранить сбои в работе телефона обнаруженные при его эксплуатации... .<br>Такое часто бывает у телефонов NOKIA - они выпускают сырую модель рекламируют её, а она потом глючит.... они так приманивают деньги на дальнейшее совершествование модельного ряда..... \n',
#  88: '<p> Маленький принц смотрел на фонарщика, и ему все больше нравился этот человек, который был так верен своему слову.<br></p>. \n',
#  89: '<p> Осень<br>Пришла осенняя пора. Опустели лесные поляны. Чаще льют дожди. Над землей ползут хмурые\xa0тучи.Ветер шуршит сухими листьями. Птицы улетают зимовать на юг. </p>. \n',
#  90: '<p> Масса вещества=массовая доля*масса раствора=0,25*40=10 </p>. \n',
#  91: '<p> 1. С ударным личным. Молчат, гудят, урчит, горит<br>\xa01. С безударным , 1 спр. Они работают, стирают, сохнут, украшают, плачут, благодарят, шепчет, напишет, зеленеет, летает, кашляет.<br>\xa03. С безударным, 2 спр. Они ходят, косит, обидит, барабанит, терпит. </p>. \n',
#  92: 'equine - общее название для всех лошадей, например для зебр. А horse - это тупо лошадь.. \n',
#  93: '<p> Может люди?????или надо именно объекты? </p>. \n',
#  94: 'Лучше взаимно. \n',
#  95: 'Спавн меню уже встроено. Делаешь как на картинке, только вместо -skip_reg прописываешь -dbg.<br>. \n',
#  96: 'Галина Радионова всему тебя надо учить по два раза ты хоть записывай или чаще этим занемайся.. \n',
#  97: 'Мои настройки - Приватность. \n',
#  98: 'Суки поганые себе кормушку устроят..... \n',
#  99: 'Бесплатные советники не предназначены для торговли. <br>Бесплатные советники производятся или для демонстрационных целей, чтобы показать, как они работают, как их устанавливать, или производятся в качестве "слонов для бесплатной раздачи". <br> <br>Источник: Использование роботов на Форексе. \n',
#  100: 'У меня бабушка по паспорту была Елизавета, а все всегда звали ее Зоей. На мой взгляд ничего страшного в этом нет. У каждого свои странности - и эта не самая странная.... \n',
#  101: '0,85=1/(1-d)^2<br>(1-d)^2=1/0,85<br>(1-d)=корень (1/0,85)<br>d=1-корень (1/0,85)=-0.0847. \n',
#  102: 'Потому, что вокруг слишком много соблазнов! Любимый уходит в армию, а так хочется нежности и ласки! А тут ещё куча подруг, у которых личная жизнь бъёт ключом, вот и ей бедняжке очень хочется... А когда ещё начинаются разговоры "доброжелателей" о том, что жизнь одна и жить надо сейчас, а если разок куда-нибудь сходить то никто не узнает. Так и получается, что не дожидаются они своих парней.. \n',
#  103: 'Интересное сообщение )). \n',
#  104: '<div> <div> <div>1</div></div> <div>Для подключения безлимитного интернета Теле2 необходимо активировать функцию «Интернет с телефона». Именно она позволяет выходить в интернет с любого приложения по довольно низкой цене.</div> </div> <div> <div> <div>2</div></div> <div>Также подключить интернет помогает функция «Безлимитная Opera Mini». Необходимо подключить услугу GPRS, загрузить приложение Opera Mini, которое можно cкачать с различных ресурсов. Также есть специальное приложение Opera Mini для Теле2, имеющее довольно широкий спектр дополнительных функций. </div> </div> <div> <div> <div>3</div></div> <div>Помните, что безлимитный интернет доступен не во всех городах России, поэтому перед подключением необходимо зайти на официальный сайт Теле2 в личный кабинет и в разделе «Тарифы и услуги» открыть вкладку «Пакеты и скидки», узнать всю необходимую информацию о подключении Теле2. Оплата будет зависеть от места вашего проживания.</div> </div> <div> <div> <div>4</div></div> <div>В том случае, если при подключении у вас возникают проблемы, то вы можете обратиться по телефону в службу поддержки оператора Теле2. Для этого наберите номер 693. По данному бесплатному номеру можно проконсультироваться относительно тарифного плана и возможностей безлимитного интернета. </div> </div> <div> <div> <div>5</div></div> <div>В самом крайнем случае вам на помощь могут прийти операторы Теле2 ближайшего офиса. В данной компании консультанты помогут осуществить подключение и окажут дополнительную помощь. Не забудьте взять с собой документ, подтверждающий личность.<br>Действительно, подключить услугу безлимитного интернета от Теле2 довольно просто. </div> </div>. \n',
ённый в них. В перевёрнутый мир. И вот, что тогда я думаю: если здесь всё не так, как надо, то может быть, мир перевёрнут не там, а здесь. И это здесь я живу в перевёрнутом мире. А тот мир – мир единственно настоящей реальности, такой, каким он и должен быть.<br> Жарким летом лужи высыхают быстро, и солнце приятно согревает, но почему-то порой щемит и замерзает сердце, и вспоминается библейский потоп…<br><br>(с) Наталья Ладнева. \n',
#  114: 'две недели назад проехал самостоятельно по маршруту Гонконг-Таиланд. Никаких проблем. Для посещения Китая точно понадобится виза, в Гонконг жители РФ могут приезжать без визы. А вообще все легко и просто :). \n',
#  115: '.. \n',
#  116: 'В основном солировал Джон, даже в песне о самом себе! <br><br>Пол солировал редко, но метко - для этой песни он несколько месяцев тренировал свое горло - и его исполнение стало просто уникальным: <br> <br>http://www.youtube.com/watch?v=IzxFL6QYjMo&amp;feature=related. \n',
#  117: 'У каждого свои обьяснения. У меня есть своя линия убежденности. Я ее никому не навязываю, а лишь высказываю, отвечая на этот вопрос. Нечто можно обьяснить лишь - замкнутостью времени, парадоском, без прадокса это не реально обьяснить. Парадокс в том, что точка начала и точка конца это одна и таже точка, она называется - арагоническая точка. То есть, если мы рассматриваем теорию большого взрыва, то - вот этот материальный мир совсеми галактиками и т.д., в одной из точки времени начнет сворачиваться - концентрироваться, видоизменяться из физичекого свойства в энергетическо-информационное, либо еще в какое-то, и затем, когда плотность дойдет до предела, грубо говоря - материальная реальность уменьшится очень, то тогда и произойдет большой взрыв. Это и можно назвать арогонической точкой - ЗАМКНУТОСТЬ ВРЕМЕНИ, понимаете.... \n',
#  118: 'Та какая песня! Вы на удар смотрите, в прыжке рукой по морде! Вот это да, это наш старче - Блюс Ли обзавидовался бы!. \n',
#  119: 'HDD это накопитель, а не видеокарта.<br><br>HDD https://ru.wikipedia.org/wiki/Жёсткий_диск на нем все файлы сохраняются. Систему на него же устанавливаешь.. \n',
#  120: '<p> Школа под номером 1514 </p>. \n',
#  121: ':) Беру оптом!!!!. \n',
#  122: 'Напиши оценки, но скорее всего будет спорная. \n',
#  123: 'Огонь-да, а вот у тебя на картинке-только пепелище осталось))). \n',
#  124: 'от свадьбы.<br>если получится<br>. \n',
#  125: 'Наверное у них тоже дерьмократы были. \n',
#  126: 'Олово, паяльник, флюс и дуй паять.. \n',
#  127: 'Интересный вопрос. Я вот до сих пор не знаю, выхожу я в Интернет или вхожу.. \n',
#  128: 'Если рассматривать в целом интернет как средство общения и как возможность интеллектуально развиваться, то большинство интернет-ресурсов несут полезную информацию. Естественно, прочитанный и усвоенный интересный контент несёт определённую функцию по развитию интеллекта человека. Делаю здесь маленькое примечание, касающееся сайтов обманщиков, которых в мировой сети предостаточно. Они никакую полезную роль не играют. Всё зависит от цели, которую поставил конкретный пользователь сети. Если он поставил цель освоить английский язык, значит он и выбирает для повышения своего интеллектуального уровня соответствующий сайт. Внесу и своё личное предложение относительно рекомендации хорошего ресурса. Мне например, он нравится тематикой, направленной для человека, проявляющего интерес к интернету. Вот название сайта и вся информация по интеллектуальному развитию: Интернет-что он может дать. Судите сами по кругу рассматриваемых вопросов и очень востребованной, популярной теме. Вот описание предлагаемого ресурса:. \n',
#  136: '<p>22 июня 1941 года</p> <p>Казалось, было холодно цветам,<br>и от росы они слегка поблёкли.<br>Зарю, что шла по травам и кустам,<br>обшарили немецкие бинокли.</p> <p>Цветок, в росинках весь, к цветку приник,<br>и пограничник протянул к ним руки.<br>А немцы, кончив кофе пить, в тот миг<br>влезали в танки, закрывали люки.</p> <p>Такою все дышало тишиной,<br>что вся земля еще спала, казалось.<br>Кто знал, что между миром и войной<br>всего каких-то пять минут осталось!</p> <p>Я о другом не пел бы ни о чем,<br>а славил бы всю жизнь свою дорогу,<br>когда б армейским скромным трубачом<br>я эти пять минут трубил тревогу.</p>. \n',
#  137: 'Начать с поездки (буксировки) в СЕРВИС!!!!. \n',
#  138: 'Это не алабай. <br>Это щенок пиренейской горной собаки. Стандарт породы FCI №137: <br>Страна происхождения: <br>Франция <br>Классификация FCI: <br>2-я группа, молоссы, горные собаки <br>Исходное название: <br>Chien de Montagne des Pyrenees <br>Другие названия: <br>Пиренейская горная собака. Большая пиренейская собака. <br> <br>. \n',
#  139: '<p>9+5=14ч содержится гилицерина и соли</p> <p>109,2:14=7,8- составляет одна часть</p> <p>9+5+6=20ч- составляет весь раствор</p> <p>7,8*20=156- масса раствора</p> <p>\xa0</p> <p>\xa0</p> <p>\xa0</p> <p>\xa0</p> <p>\xa0</p> <p>\xa0</p>. \n',
#  140: 'Общение в реале за чашкой чая или на природе, поедая шашлыки или сидя в уютном кафе... разве это можно сравнить с общением в интернете.. . Вот если реальное общение с человеком, который тебе интересен и приятно общаться, неозможно, тогда другое дело. В этом случае интернет вне конкуренции.. \n',
#  141: 'да. из Богоявленского Собора беру ежегодно - 5 литров, которых хватает до следующего Крещения Господня. Добавляю по-20=25 грамм во всё приготавливаемое из пищи, осенив Святым Знамением. <br>С праздником-! <br>http://dic.academic.ru/pictures/wiki/files/66/Bogoyavlensky_(Epiphany)_cathedral_in_Yelokhovo_51.jpg. \n',
#  142: '<p>дано: авсд - параллелограмм<br><br>ам=мб мс=мд.<br><br>доказать: авсд - прямоугольник<br><br>доказательство: так как ам=мб ад=вс и мс=мд, то треугольники амд и амс равны по третьему признаку(по трём сторонам)</p> <p><br>так как эти треугольники равны, то и углы у них равны(угол всм = углу мда; угол свм = углу дамЖ угол смв = углу дма) , нас интересуют углы дам и свм. они односторонние, значит их сумма должна быть 180 градусов (так как вс и ад параллельны а ав их пересекает, а при пересечении двух параллельных прямых третьей сумма односторонних углов равна 180 градусов). следовательно угол дам и угол сбм = 90 градусов, а если в параллелограмме хотябы один угол прямой, то это прямоугольник.</p>. \n',
#  143: 'Это ненормально, хоть и говорят там -любви все возрасты покорны ,)))<br>Скорее всего это только из-за денег - других причин я не вижу!<br>. \n',
#  144: 'google.ru/imghp<br>сюда заходишь и просто перетаскиваешь картинку в поле. \n',
#  145: 'Все уже сложилось и даже очень! ))). \n',
#  146: 'при создании вопроса внизу есть кнопка создать опрос. \n',
#  147: 'Рвутся когда встает!. \n',
#  148: 'Встречала в игре "Поле Чудес" этот вопрос - "Американский президент", ответ должен был состоять из семи букв. Правильным ответом именно к игре "Поле Чудес" был - Джон Фицжеральд КЕННЕДИ - 35 - ый президент США.. \n',
#  149: 'бардовскую песню, типо Высоцкого (надеюсь правильно накалякала). \n',
#  150: 'Что можно с этим делать?<br>Ответ: Удалить на хрен это дерьмо, и поставить нормальную ОС!. \n',
#  151: 'Причины зарождения проституции различны. Для большинства девушек это способ заработать, а в бедных странах чуть ли не единственная возможность выжить . Другая причина – постоянный спрос на продажную любовь со стороны сильного пола. Их потребность в сексе выше чем у женщин, и это заложено самой природой. А пока есть спрос, будет и предложение.. \n',
#  152: 'Отношения будут развиваться трудно. Взаимопонимания нет.. \n',
#  153: 'И не пытаться. Даже если обманывает, то не тебя а себя.. \n',
#  154: 'у нас один ориентир - СОЛНЦЕ. \n',
#  155: 'В Пскове. \n',
#  156: 'Щас вся ВТО под вопросом..... \n',
#  157: '<p> Потому что волосы при расчесывании пластм.расческой электризуются. </p>. \n',
#  158: 'Зарегистрируйте новый ящик. \n',
#  159: 'Думаю это уже не загорами.. постепенно тенденция руской попсы затухает на западе.. и многие страны с удовольствием приглашают рок музыкантов а не нашу попсу. Да и у нас стали появляться более развитые кейпинг шоу... \n',
#  160: 'Дом, квартира – Это символ вашей личности, вашего положения в обществе. В любом случае, центральный компонент толкования лестницы - это получение особого, хотя и шаткого, доступа к необходимым ценностям. Такой доступ часто сопровождается потерей права доступа или удачи. <br> <br>Если вы очутились в ситуации, где без лестницы не обойтись, то возможно, вы испытываете недостаток в средствах. Мы остро чувствуем, насколько мы зависим от земного притяжения и ограничены в возможности высоко подниматься. Если в снах не предоставляется возможность взЛЕТЕТЬ, тогда лестница - единственный выход из положения.. \n',
#  161: 'string[] lines; <br> lines = System.IO.File.ReadAllLines("yrfile.txt"); <br> <br>Собссно все. Читаем файл в память, делаем что нам надо и записываем на место.. \n',
#  162: 'купи у нас iRiver S100, новый, 8 Гб <br>цена 2000 руб. , а в магазине 2600....3200 (в Йоне) <br>держит до 40 часов вроде <br> <br>подарил сыну, а он не слушает музыку <br>большой экран, отличный звук (iRiver этим не грешит!!! ) <br> <br>inkpost@yandex.ru (я живу в Москве)<br>. \n',
#  163: 'блёндинку спинным мозгом чую... здарофф извращенка!. \n',
#  164: '1 столбик: какой, <br>2 столбик: кто .... \n',
#  165: 'Вот это клиническое мышление!. \n',
#  166: 'Из базы данных космической информации следует, что на Земле больше не будет мировых войн.<br>Большие войны предвидятся, но без серьёзного участия России.<br>Для России уготованы только небольшие военные конфликты.<br>Кроме того отправка российского военного контингента за рубеж в 2013 году.. \n',
#  167: 'своей любовью ибо всем остальным можно удивлять все остальные ночи). \n',
#  168: 'не корми её. \n',
#  169: 'и то и другое и можно по больше)))))))))). \n',
#  170: 'должен знать хотяб все элементарное а там разберешься. \n',
#  171: 'точки.. \n',
#  172: 'нет <br>случайность, повторившаяся дважды - закономерность. только не всегда удается найти закон, по которому все сошлось. \n',
#  173: 'эмм. . ничего.. обычный кроль будет.. только породу испортите и все )) а обычный это какой ?? у всех породы есть или под словом обычный вы имели ввиду кролика мясной породы ?. \n',
#  945: 'Белье))). \n',
#  946: 'От задаваемой нагрузки.. \n',
#  947: 'Пока в армию не стали призывать зеков, там не знали слово дедовщина. После армии славные гвардейцы ринулись в ментовку, а нармальные пацаны на целину, "бывших" с удовольствием туда брали. Расцветать малина начала в начале 60х годов, и уже в 80е очень себя конкретно чувствовала, пустив корни во властных коридорах. Сегодня в стране по сути правят всем по зековским законам. Та же чиновничья спираль, с низов до верхов пропитанная сплошными взятками и откатами, и те же воровские понятия, об этом говорят все, но МЫ - трусливы, живем и думаем только о себе. Время упущенно, чтобы возмущатся открыто, у НАС нет того мужества которым славились нанаши деды. Наша жизнь - удел слабых, и на НАШ писк никто не обратит внимания, потому что мы, по оценкам некоторых политиков, быдло. Спившиеся и до неприличия обленившиеся людишки, за сто грамм готовые на все. Думайте что хотите, написал то, что вижу, и про себя конечно же.... \n',
#  948: 'если в видеопотоке поддерживаются субтитры то нужно нажать на кнопку "Воспроизведение" вверху, потом выбрать "Слова песен, субтитры и подписи", затем включить если доступно. \n',
#  949: 'Понимаешь, и среди мужиков встречаются болтливые..... \n',
#  950: 'Я, жена, дети.. \n',
#  951: 'да каждая девушка думает что у нее пару -тройку кг лищних..... \n',
#  952: '<h2>Краткое описание</h2> <h2>Лицензирование</h2>. \n',
#  953: 'смаж. \n',
#  954: 'То же самое, что "мужчина" говорит.... : "Мамка, а она меня обидела !!!". \n',
#  955: 'сердце придложишь - схватят за горло<br>руку предложишь - вырвут с плечём. \n',
#  956: '<p> Реакции есть на фотографии </p>. \n',
#  957: '<p> 0,2311............... </p>. \n',
#  958: 'Пиратку ставил? Хосты обрублены. Там же должна быть ссылка со справкой, там ссыль на прогу для устранения. Это если у тебя лицензия, если пиратка-вообще не заморачивайся. иначе слетит.. \n',
#  959: '- Он сказал: если узнает, что я ещё раз ему изменила, то сразу застрелится. С тех пор я ему больше ничего не рассказываю и уже семь раз спасла его от смерти!. \n',
#  960: 'не есстественнол<br>. \n',
#  961: '<br>Ты когда научилась, дролечка, <br>пить одна? <br>Наливай-ка и мне — вот столечко,, , <br>Пьем до дна. <br> <br>Чем тебе, синеглазка милая, <br>я вдруг стал не хорош? <br>Заливаешь глаза текилою.. . <br>Иль в морду хошь?<br>. \n',
#  962: 'Встречал таких, но они ходили передо мной, часто опуская голову, изредка поглядывая на меня... у тебя за спину заходил-это перебор, смешно... я бы не стал крутиться, как волчок, тормознул бы его и спросил чего он ,.суетится?"..))что по мне, то это люди-пизд... болы, прямо и кратко скажем... доверия к ним нОль..). \n',
#  963: 'В определении формальных источников права. <br>Вопрос обширный, по нему пишут диссертации, можете воспользоваться поисковиками и прочитать подробнее.. \n',
#  964: '<p><br>(пи*R*138):180=15</p> <p>(пи*R*23):30=15</p> <p>пиR=30*15:23</p> <p>R = 450:23:пи</p> <p>R = 6,2</p> <br>. \n',
#  965: 'есть. 400 р. \n',
#  966: 'Соскоп и на экспертизу! Кто же вам заочно, скажет??. \n',
#  967: 'массовое число А-сумма числа протонов и электронов в атома. Зарядовое число Z-количество протонов. Их можно определить по таблице Менделеева. Массовое число находится под элементом, обычно представляя огромную десятичную дробь, а Z-порядковый номер химического элемента. \n',
#  968: 'Блин-малина!!!! И вот меня такое интересует, а ведь я уже старенькая и хотелось бы перед смертью всё же узнать. \n',
#  969: 'ктоже от активного мальчика откажется....даже мужчины многие не против... <br> <br>хотя иногда хочется всего вылизать и помучить немножко... под настроение. <br> <br>побольше Вам мужчины в жизни актива (в смысле большие активы...) и побольше пассива, в смысле пассивных конкурентов и податливых женщин... <br> <br>разных вообщем. и всего!. \n',
#  970: 'Мир\xa0— человечество в целом\xa0— подчиняется Сатане, поддаваясь его влиянию и пренебрегая требованиями Бога. Поэтому Иисус Христос назвал Сатану «правителем этого мира» (Иоан. 14:30; Эф. 2:2). Сатана также назван в Библии «богом этой системы вещей», и люди, принадлежащие к этой системе, почитают его своими религиозными обычаями (2\xa0Кор. 4:4; 1\xa0Кор. 10:20).<br>Неудивительно, что в 1\xa0Иоанна 5:19 говорится: «Весь мир лежит во власти Злого». Однако Сатана будет властвовать только ограниченное время, пока это допускает Всевышний Бог, Иегова.. \n',
#  971: 'законы социума ). \n',
#  972: 'А почему? <br>не надо путать с "А зачем? " <br>А что мне с этого будет? <br>Ты кто? <br>Ты меня уважаешь? <br>Ты все сделал? <br>А что я должен был сделать? <br>....<br>. \n',
#  973: 'http://yandex.ru/yandsearch?text=+Р·Р°РїСѓСЃС‚РёС‚СЊ+РёРіСЂСѓ+СЃРёР» РµРЅС‚+С… Р°РЅС‚РµСЂ<br><br>. \n',
#  974: '<h2>Краткое описание</h2> <h2>Лицензирование</h2>. \n',
#  975: 'Лишь только при одном условии - что украинец имеет разрешение на работу и трудоустроен на территории РФ по договору с установленным сроком его окончания. Однако, всё это отдается на усмотрение банка. Ведь человек в любой момент может в одностороннем порядке расторгнуть договор о найме и тут же исчезнуть на своей территории с невыплаченным банковским кредитом. <br>Ищи его - свищи!. \n',
#  976: 'Если директору понравитесь, то да.. \n',
#  977: 'на кастуйте орду гулей, обычно это помогает.. \n',
#  978: 'Как узнать будущее по нумерологии....<br><br>Это не только самый распространенный способ, но и один из самых правдивых. Потому что влияние цифр на судьбу человека велико. Доказательством этому служат религии, в каждой из которых цифрам отводится определенная роль. Узнать будущее по нумерологии возможно еще со времен пифагорейцев, и раз так долго это знание остается популярным, значит, что-то в нем определённо есть.<br><br><br><br>Итак, я хочу узнать свое будущее. Беру дату своего рождения, например, 31.03.1984, и складываю все цифры последовательно до образования однозначного числа следующим образом: 3+1=4; 0+3=3; 1+9+8+4=22; 4+3+22=29; 2+9=11; 1+1=2. А далее, смотрю, что означает моя цифра.<br><br> Судьба приготовила вам завидную карьеру начальника, работа и карьера всегда будут для вас на первом месте.<br> Ваш приоритет по жизни – друзья и близкие люди, ради общения с которыми вы легко можете пожертвовать всем остальным, вы родились стать прекрасным семьянином.<br> Вы творческий человек и успех вам гарантирован там, где вы сможете применить свои таланты «художника».<br> Вы родились, чтобы стать трудоголиком, однако, без замашек на лидерство. Вы прекрасный исполнитель, а потому большего успеха
#  989: 'Сочнее, жирнее и вкуснее. Оттого и дороже.. \n',
#  990: '<p> (x-7)*(x+9)=x^2-9<br>x^2+9x-7x-63-x^2+9=0<br>сокращай и решишь там дальше уже? </p>. \n',
#  991: 'Рассыпчатая хороша тем что ее можно нанести на лицо тонким слоем кистью.... и еще у рассыпчатой пудры Иса Дора приличный объем-хватит надолго... у меня была рассыпчатая пудра Perfect Loose Powder- банка 18 грамм!! ! если не ошибаюсь.... хорошо подходит для жирной и комбиниронной кожи -неплохо матирует!... отлично подстраивается под цвет кожи-у меня был 1 тон- универсальный прозрачный. Мне и компактная пудра нравится в этой марке- тоже можно тонким слоем кистью наносить вообщем то. Так что-объем внушительный- это главный плюс.. \n',
#  992: 'ну, был такой один, прохода не давал, постоянно в соц. сети писал, каждый раз с новых страниц, ибо банила. . исполнила его желание, сблизилась с ним (от скуки, если честно да и страшным он не был+был богатый, но просто не на мой вкус ) , так у него от волнения кое-что не заработало, вот умора-то была!))). \n',
#  993: 'Когда мне помогает дочка, она забирает у меня магические знания, её воспитывал я и по этому у неё есть ко мне допуск. Не с кем другим своим куском хлеба я делиться не буду.. \n',
#  994: 'можно назло). \n',
#  995: 'уж точно не я. \n',
#  996: 'Если мне какую курву <br>Вдруг захочется промерять, <br>То курвиметром я точно <br>Там где надо проведу !. \n',
#  997: 'Несколько маленьких ящеров засели или змею.. \n',
#  998: 'Не-а! Должно быть, "шуры-муры" крутят! :)) <br> <br>. \n',
#  999: 'Поддерживать (в общем, мне это и не надо. Утратил эту способность со временем), меняться в "лучшую" сторону.. \n',
#  ...}

# %%
def preprocess_txt(line):
    line = " ".join(str(element) for element in line)
    line = clean_text(line)
    remowe_stopwords(line)
    lem_words(line)
    return line

# %%
def find_answer(question):
    preprocessed_question = preprocess_txt(question)
    n_w2v = 0
    vector = np.zeros(100)
    for word in preprocessed_question:
        if word in model_w2v_sp.wv:
            vector += model_w2v_sp.wv[word]
            n_w2v += 1
    if n_w2v > 0:
        vector = vector / n_w2v
    answer_index = index.get_nns_by_vector(vector, 1)
    return loaded_dict[answer_index[0]]

# %%
def get_answer(text_input):
    #
    #print('test_prod',test_prod)
    predict = model.predict(vectorizer.transform(text_input))
    print('predict',predict)
    if predict == 0:

        print('Ответ на ваш вопрос:',find_answer(text_input))
    else:
        test_prod = preprocess_txt(text_input)
        find_similar_products(text_input, indexer, model_w2v_prod)
        print('Обратите внимание на след. продукты:')
        for el in similar_products:
            print('Название -', df1['title'].iloc[el],', id-',df1['product_id'].iloc[el])

# %%
get_answer(['юбка красная короткая'])
# Out:
# predict [1]
# Обратите внимание на след. продукты:
# Название - Новый кошелек , id- 584d1969479e757c213e9366
# Название - Кофта на мальчика , id- 58fbf86c9e94ba78b77dfec2
# Название - Рубашка , id- 57ce5eecd53f3d0e6f856060
# Название - Очки Cartier Edition Santos Dumont , id- 59dbbd2922a449a8e6351292
# Название - Парка для девочки John Lewis , id- 5acdc463f094f35087394661

# %%
get_answer(['сколько солдат в роте'])
# Out:
# predict [0]
# Ответ на ваш вопрос: а я почем знаю.
